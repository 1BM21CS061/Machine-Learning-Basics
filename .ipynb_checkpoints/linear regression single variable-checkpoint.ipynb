# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
df = pd.read_csv(r"C:\Users\G Sai Madhav\Desktop\robotics\ML\LINEAR_REGRESSION\linear_reg_single\linear_reg.csv")
print(df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.scatter(df.area,df.price)
plt.plot(df.area,df.price)
plt.xlabel("area")
plt.ylabel("price")
#plt.plot(d.area,reg.predict(d[['area']]),color='red')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# D:\conda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
reg.predict([[5000]])
# Out:
# D:\conda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
d = pd.read_csv(r"C:\Users\G Sai Madhav\Desktop\robotics\linear_reg_2.csv")
print(d.head(3))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7520\2081938368.py in <module>
# ----> 1 d = pd.read_csv(r"C:\Users\G Sai Madhav\Desktop\robotics\linear_reg_2.csv")
#       2 print(d.head(3))
#
# D:\conda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
p=reg.predict(d)

# %%
d['prices'] = p
print(d)
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9    230  2.118476e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
df1 = pd.read_csv(r"C:\Users\G Sai Madhav\Desktop\robotics\ML\LINEAR_REGRESSION\linear_reg_ex.csv")
print(df1)
# Out:
#     year        income
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# ...

# %%
reg = linear_model.LinearRegression()
reg.fit(df1[['year']],df1.income)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# D:\conda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
# %matplotlib inline
plt.scatter(df1.year,df1.income)
plt.xlabel("year")
plt.ylabel("income")
#plt.plot(d.area,reg.predict(d[['area']]),color='red')
plt.plot(df1.year,df1.income,color="red")
plt.plot(df1.year,reg.predict(df1[['year']]),color='blue')

# %%
import pickle

# %%
with open('model_pickle','wb') as f:
    pickle.dump(reg,f)

# %%
with open('model_pickle','rb') as f:
    model = pickle.load(f)

# %%
model.predict([[5500]])
# Out:
# D:\conda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([927448.63013699])
